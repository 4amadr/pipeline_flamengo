# %%
import pandas as pd 
import numpy as np

df_24= pd.read_csv("flamengo_2024.csv")
df_25 = pd.read_csv("flamengo_2025.csv")
df_24.head()
# Out:
#          Date   Time          Comp        Round  Day Venue Result  GF  GA  \
# 0  2024-04-02  17:00  Libertadores  Group stage  Tue  Away      D   1   1
# 1  2024-04-10  21:30  Libertadores  Group stage  Wed  Home      W   2   0
# 2  2024-04-14  16:00       Série A  Matchweek 1  Sun  Away      W   2   1
# 3  2024-04-17  21:30       Série A  Matchweek 2  Wed  Home      W   2   1
# 4  2024-04-21  16:00       Série A  Matchweek 3  Sun  Away      D   0   0
#
#          Opponent   xG  xGA  Poss  Attendance                 Captain  \
# 0  co Millonarios  NaN  NaN    54     22205.0  Giorgian De Arrascaeta
# 1    cl Palestino  NaN  NaN    63         NaN  Giorgian De Arrascaeta
# 2  Atl Goianiense  1.2  1.6    67     31617.0  Giorgian De Arrascaeta
# 3       São Paulo  1.3  0.7    47     45166.0          Bruno Henrique
# 4       Palmeiras  0.2  0.4    50     29956.0  Giorgian De Arrascaeta
#
#   Formation Opp Formation Referee  Match Report Notes
# 0   4-2-3-1         4-4-2     NaN  Match Report   NaN
# 1   4-2-3-1       4-2-3-1     NaN  Match Report   NaN
# 2   4-2-3-1       4-1-3-2     NaN  Match Report   NaN
# 3   4-2-3-1         3-4-3     NaN  Match Report   NaN
# 4   4-2-3-1         3-4-3     NaN  Match Report   NaN

# %%
# Convertendo 'Attendance' para valor numérico
df_24['Attendance'] = pd.to_numeric(df_24['Attendance'], errors='coerce')

# Substituindo valores NaN em xG e xGA pela média arredondada a 2 casas decimais
df_24[['xG', 'xGA']] = df_24[['xG', 'xGA']].apply(lambda col: col.fillna(np.round(col.mean(), 2)))

# Calculando a média de Attendance ignorando NaN
attendance_mean = df_24['Attendance'].mean()

# Substituindo NaN em Attendance pela média ded publico nos estádios
df_24['Attendance'] = df_24['Attendance'].fillna(np.round(attendance_mean, 0) if not np.isnan(attendance_mean) else 0)

# as colunas "notes" e "referee" estão todas em NaN, mas não são importantes para a nossa analise por isso vamos exclui-la
df_24.drop(columns=['Referee', 'Notes'], inplace=True)

# %%
# separando dados
# iniciando a separação dos dados por período, inicialmente vamos separar até a data em que o tite foi demitido 30/09/2025
# após isso vamos juntar o fim da época que é quando o Felipe Luis assumiu até a presente data

# Convertendo a coluna 'Date' para o formato datetime
df_24['Date'] = pd.to_datetime(df_24['Date'], format='%Y-%m-%d')

df_24['Date'] = pd.to_datetime(df_24['Date'], dayfirst=True)
data_corte = "2024 - 09 - 30"
data_corte = pd.to_datetime(data_corte, dayfirst=True)

# criando dois dfs separados

# tite
df_tite = df_24[df_24['Date'] <= data_corte]
df_felipe_luis = df_24[df_24['Date']  > data_corte]

# unindo o df de 2024 após a demissão do tite ao df de 2025
df_2025 = pd.concat([df_felipe_luis, df_25], ignore_index=True)

# mostrando os dados do período do tite
print("periodo do tite: ", df_tite)

df_tite.head()
# Out:
# periodo do tite:           Date   Time          Comp           Round  Day Venue Result  GF  GA  \
# 0  2024-04-02  17:00  Libertadores     Group stage  Tue  Away      D   1   1
# 1  2024-04-10  21:30  Libertadores     Group stage  Wed  Home      W   2   0
# 2  2024-04-14  16:00       Série A     Matchweek 1  Sun  Away      W   2   1
# 3  2024-04-17  21:30       Série A     Matchweek 2  Wed  Home      W   2   1
# 4  2024-04-21  16:00       Série A     Matchweek 3  Sun  Away      D   0   0
# 5  2024-04-24  20:30  Libertadores     Group stage  Wed  Away      L   1   2
# 6  2024-04-28  11:00       Série A     Matchweek 4  Sun  Home      L   0   2
# 7  2024-05-04  18:30       Série A     Matchweek 5  Sat  Away      D   1   1
# 8  2024-05-07  20:00  Libertadores     Group stage  Tue  Away      L   0   1
# 9  2024-05-11  16:00       Série A     Matchweek 6  Sat  Home      W   2   0
# 10 2024-05-15  21:30  Libertadores     Group stage  Wed  Home      W   4   0
# 11 2024-05-28  21:00  Libertadores     Group stage  Tue  Home      W   3   0
# 12 2024-06-02  16:00       Série A     Matchweek 7  Sun  Away      W   6   1
# 13 2024-06-13  20:00       Série A     Matchweek 8  Thu  Home      W   2   1
# 14 2024-06-16  16:00       Série A     Matchweek 9  Sun  Away      D   1   1
# 15 2024-06-20  20:00       Série A    Matchweek 10  Thu  Home      W   2   1
# 16 2024-06-23  16:00       Série A    Matchweek 11  Sun  Away      W   1   0
# 17 2024-06-26  20:00       Série A    Matchweek 12  Wed  Away      L   1   2
# 18 2024-06-30  18:30       Série A    Matchweek 13  Sun  Home      W   2   1
# 19 2024-07-03  21:30       Série A    Matchweek 14  Wed  Away      W   4   2
# 20 2024-07-06  20:00       Série A    Matchweek 15  Sat  Home      D   1   1
# 21 2024-07-11  20:00       Série A    Matchweek 16  Thu  Home      L   1   2
# 22 2024-07-20  16:00       Série A    Matchweek 18  Sat  Home      W   2   1
# 23 2024-07-24  20:00       Série A    Matchweek 19  Wed  Away      W   2   1
# 24 2024-07-28  16:00       Série A    Matchweek 20  Sun  Home      W   2   0
# 25 2024-08-03  21:30       Série A    Matchweek 21  Sat  Away      L   0   1
# 26 2024-08-11  16:00       Série A    Matchweek 22  Sun  Home      D   1   1
# 27 2024-08-15  21:30  Libertadores     Round of 16  Thu  Home      W   2   0
# 28 2024-08-18  18:30       Série A    Matchweek 23  Sun  Away      L   1   4
# 29 2024-08-22  20:30  Libertadores     Round of 16  Thu  Away      L   0   1
# 30 2024-08-25  20:00       Série A    Matchweek 24  Sun  Home      W   2   1
# 31 2024-09-01  16:00       Série A    Matchweek 25  Sun  Away      L   1   2
# 32 2024-09-15  18:30       Série A    Matchweek 26  Sun  Home      D   1   1
# 33 2024-09-19  19:00  Libertadores  Quarter-finals  Thu  Home      L   0   1
# 34 2024-09-22  18:30       Série A    Matchweek 27  Sun  Away      L   2   3
# 35 2024-09-26  19:00  Libertadores  Quarter-finals  Thu  Away      D   0   0
# 36 2024-09-29  20:00       Série A    Matchweek 28  Sun  Home      W   1   0
#
#             Opponent   xG  xGA  Poss  Attendance                 Captain  \
# 0     co Millonarios  NaN  NaN    54     22205.0  Giorgian De Arrascaeta
# 1       cl Palestino  NaN  NaN    63         NaN  Giorgian De Arrascaeta
# 2     Atl Goianiense  1.2  1.6    67     31617.0  Giorgian De Arrascaeta
# 3          São Paulo  1.3  0.7    47     45166.0          Bruno Henrique
# 4          Palmeiras  0.2  0.4    50     29956.0  Giorgian De Arrascaeta
# 5         bo Bolívar  NaN  NaN    37     22620.0                  Gerson
# 6      Botafogo (RJ)  0.8  1.0    60     53683.0  Giorgian De Arrascaeta
# 7      RB Bragantino  1.8  0.6    56      9917.0                  Gerson
# 8       cl Palestino  NaN  NaN    64      4217.0                  Gerson
# 9        Corinthians  1.7  1.6    58     56829.0                  Gerson
# 10        bo Bolívar  NaN  NaN    50     63169.0                  Gerson
# 11    co Millonarios  NaN  NaN    62     64268.0                  Gerson
# 12     Vasco da Gama  3.8  0.1    73     62228.0                  Gerson
# 13            Grêmio  1.0  1.0    42     51785.0                  Gerson
# 14    Ath Paranaense  0.6  1.8    52     38641.0                  Gerson
# 15             Bahia  1.1  0.8    35     49909.0                  Gerson
# 16        Fluminense  2.0  0.3    46     57098.0                  Gerson
# 17         Juventude  1.6  2.2    47     12675.0                  Gerson
# 18          Cruzeiro  0.6  0.6    46     52768.0                  Gerson
# 19  Atlético Mineiro  2.1  2.4    48     33993.0                  Gerson
# 20            Cuiabá  1.4  0.8    66     54948.0                  Gerson
# 21         Fortaleza  2.0  0.4    70     57517.0                  Gerson
# 22          Criciúma  2.4  1.2    62     60127.0                  Gerson
# 23           Vitória  1.0  1.4    56     30688.0                  Gerson
# 24    Atl Goianiense  1.3  0.4    53     61883.0                  Gerson
# 25         São Paulo  0.3  1.4    40     58065.0          Bruno Henrique
# 26         Palmeiras  1.0  1.3    52     55051.0                  Gerson
# 27        bo Bolívar  NaN  NaN    64         NaN                  Gerson
# 28     Botafogo (RJ)  0.8  3.3    46     23731.0                  Gerson
# 29        bo Bolívar  NaN  NaN    26         NaN                  Gerson
# 30     RB Bragantino  1.3  1.1    55     28159.0                  Gerson
# 31       Corinthians  1.3  1.6    57     45635.0                  Gerson
# 32     Vasco da Gama  2.1  1.0    61     65200.0                  Gerson
# 33        uy Peñarol  NaN  NaN    76     64396.0                  Gerson
# 34            Grêmio  1.4  1.6    56     48504.0              David Luiz
# 35        uy Peñarol  NaN  NaN    74     38144.0                  Gerson
# 36    Ath Paranaense  0.7  0.4    69     30022.0         Gabriel Barbosa
#
#    Formation Opp Formation                       Referee  Match Report  \
# 0    4-2-3-1         4-4-2                           NaN  Match Report
# 1    4-2-3-1       4-2-3-1                           NaN  Match Report
# 2    4-2-3-1       4-1-3-2                           NaN  Match Report
# 3    4-2-3-1         3-4-3                           NaN  Match Report
# 4    4-2-3-1         3-4-3                           NaN  Match Report
# 5      3-4-3         4-3-3                           NaN  Match Report
# 6    4-2-3-1         4-4-2                           NaN  Match Report
# 7    4-2-3-1       4-2-3-1                           NaN  Match Report
# 8    4-2-3-1         4-3-3                           NaN  Match Report
# 9    4-2-3-1         3-4-3                           NaN  Match Report
# 10   4-2-3-1         4-3-3                           NaN  Match Report
# 11   4-2-3-1         5-4-1                           NaN  Match Report
# 12   4-2-3-1         3-4-3               Braulio Machado  Match Report
# 13   4-2-3-1         4-4-2                           NaN  Match Report
# 14   4-2-3-1       4-2-3-1                           NaN  Match Report
# 15   4-2-3-1       4-1-3-2                           NaN  Match Report
# 16   4-2-3-1         4-4-2                           NaN  Match Report
# 17   4-2-3-1       4-2-3-1                           NaN  Match Report
# 18   4-2-3-1         4-3-3                           NaN  Match Report
# 19   4-2-3-1       4-1-4-1                  Ramon Abatti  Match Report
# 20     4-4-2         4-5-1  Rodrigo José Pereira de Lima  Match Report
# 21   4-2-3-1       4-2-3-1                   Edina Alves  Match Report
# 22   4-2-3-1         4-4-2       Maguielson Lima Barbosa  Match Report
# 23   4-2-3-1       4-1-4-1                 Raphael Claus  Match Report
# 24   4-2-3-1         4-3-3                           NaN  Match Report
# 25   4-2-3-1       4-2-3-1                  Rafael Klein  Match Report
# 26   4-2-3-1         3-4-3                Wilton Sampaio  Match Report
# 27   4-2-3-1       4-1-4-1                           NaN  Match Report
# 28   4-2-3-1       4-2-3-1                   Bruno Arleu  Match Report
# 29   4-2-3-1       4-1-4-1                           NaN  Match Report
# 30   4-2-3-1       4-2-3-1      Gustavo Ervino Bauermann  Match Report
# 31   4-2-3-1         3-4-3                  Ramon Abatti  Match Report
# 32   4-2-3-1       4-2-3-1                 Raphael Claus  Match Report
# 33   4-2-3-1       4-2-3-1              Jesús Valenzuela  Match Report
# 34     4-4-2       4-2-2-2     Matheus Delgado Candançan  Match Report
# 35   4-2-3-1       4-2-3-1                 Facundo Tello  Match Report
# 36   4-2-3-1         3-4-3      Davi de Oliveira Lacerda  Match Report
#
#                        Notes
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                Leg 1 of 2
# 28                       NaN
# 29  Leg 2 of 2; Flamengo won
# 30                       NaN
# 31                       NaN
# 32                       NaN
# 33                Leg 1 of 2
# 34                       NaN
# 35   Leg 2 of 2; Peñarol won
# 36                       NaN
# C:\Users\Natan\AppData\Local\Temp\ipykernel_3284\2405766515.py:10: UserWarning: Parsing dates in %Y - %m - %d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   data_corte = pd.to_datetime(data_corte, dayfirst=True)
#         Date   Time          Comp        Round  Day Venue Result  GF  GA  \
# 0 2024-04-02  17:00  Libertadores  Group stage  Tue  Away      D   1   1
# 1 2024-04-10  21:30  Libertadores  Group stage  Wed  Home      W   2   0
# 2 2024-04-14  16:00       Série A  Matchweek 1  Sun  Away      W   2   1
# 3 2024-04-17  21:30       Série A  Matchweek 2  Wed  Home      W   2   1
# 4 2024-04-21  16:00       Série A  Matchweek 3  Sun  Away      D   0   0
#
#          Opponent   xG  xGA  Poss  Attendance                 Captain  \
# 0  co Millonarios  NaN  NaN    54     22205.0  Giorgian De Arrascaeta
# 1    cl Palestino  NaN  NaN    63         NaN  Giorgian De Arrascaeta
# 2  Atl Goianiense  1.2  1.6    67     31617.0  Giorgian De Arrascaeta
# 3       São Paulo  1.3  0.7    47     45166.0          Bruno Henrique
# 4       Palmeiras  0.2  0.4    50     29956.0  Giorgian De Arrascaeta
#
#   Formation Opp Formation Referee  Match Report Notes
# 0   4-2-3-1         4-4-2     NaN  Match Report   NaN
# 1   4-2-3-1       4-2-3-1     NaN  Match Report   NaN
# 2   4-2-3-1       4-1-3-2     NaN  Match Report   NaN
# 3   4-2-3-1         3-4-3     NaN  Match Report   NaN
# 4   4-2-3-1         3-4-3     NaN  Match Report   NaN

# %%
# começando analises do flamengo de Tite

print(" ======================= Analises do flamengo de Tite =======================")
# Resultados com o tite
df_derrotas = df_tite[df_tite["Result"] == "L"].shape[0]
df_empates = df_tite[df_tite["Result"] == "D"].shape[0]
df_vitorias = df_tite[df_tite["Result"] == "W"].shape[0]

print(f"O flamengo de tite deve: ", df_derrotas, " derrotas, ", df_empates, " empates e ", df_vitorias , " vitorias")

# como era o desempenho tático?
# média de posse de bola
media_posse = df_tite["Poss"].mean()
print(f"Média de posse de bola do Flamengo de Tite: {media_posse:.2f}")

# formação mais usada
formacao_mais_usada = df_tite["Formation"].max()
# formação menos usada
formacao_menos_usada = df_tite["Formation"].min()
print(f"Formação mais usada: ", formacao_mais_usada, "VS formacao menos usada: ", formacao_menos_usada )

# Média de xG, gols esperados
media_xG = df_tite["xG"].mean()
print(f"Média de xG:  {media_xG:.2f}")

# Média de xAG, gols esperados que aconteceram
media_xGA = df_tite["xGA"].mean()
print(f"Média xGA: {media_xGA:.2f}")




# Desempenho em casa
print("\n === Desempenho em casa === ")

# Número total de jogos em casa
total_jogos_casa = df_tite[df_tite["Venue"] == "Home"].shape[0]

# Número de vitórias em casa
vitorias_casa = df_tite[(df_tite["Venue"] == "Home") & (df_tite["Result"] == "W")].shape[0]

# Média de vitórias em casa (percentual de vitórias)
percentual_vitorias_casa = (vitorias_casa / total_jogos_casa) * 100 if total_jogos_casa > 0 else 0
print(f"\nPorcentagem de vitórias em casa: {percentual_vitorias_casa:.2f}%")

# Média de xG em casa
media_xG_casa = df_tite[df_tite["Venue"] == "Home"]["xG"].mean()
print(f"Média de xG em casa: {media_xG_casa:.2f}")

# Gols feitos em casa
gols_feitos_casa = df_tite[df_tite["Venue"] == "Home"]["GF"].sum()
gols_feitos_casa_media = gols_feitos_casa / total_jogos_casa if total_jogos_casa > 0 else 0
print(f"Gols feitos em casa (Total): {gols_feitos_casa}")
print(f"Gols feitos em casa (Média): {gols_feitos_casa_media:.2f}")

# Gols concedidos em casa
gols_concedidos_casa = df_tite[df_tite["Venue"] == "Home"]["GA"].sum()
gols_concedidos_casa_media = gols_concedidos_casa / total_jogos_casa if total_jogos_casa > 0 else 0
print(f"Gols concedidos em casa (Total): {gols_concedidos_casa}")
print(f"Gols concedidos em casa (Média): {gols_concedidos_casa_media:.2f}")
# Out:
#  ======================= Analises do flamengo de Tite =======================
# O flamengo de tite deve:  11  derrotas,  8  empates e  18  vitorias
# Média de posse de bola do Flamengo de Tite: 55.14
# Formação mais usada:  4-4-2 VS formacao menos usada:  3-4-3
# Média de xG:  1.39
# Média xGA: 1.12
#
#  === Desempenho em casa ===
#
# Porcentagem de vitórias em casa: 68.42%
# Média de xG em casa: 1.37
# Gols feitos em casa (Total): 32
# Gols feitos em casa (Média): 1.68
# Gols concedidos em casa (Total): 14
# Gols concedidos em casa (Média): 0.74

# %%
# Jogos fora de casa

print("\n === Desempenho fora de casa ===")
total_jogos_visitante = df_tite[df_tite["Venue"] == "Away"].shape[0]

# Número de vitórias fora de casa
vitorias_visitante = df_tite[(df_tite["Venue"] == "Away") & (df_tite["Result"] == "W")].shape[0]

# Média de vitórias fora de casa (percentual de vitórias)
percentual_vitorias_visitante = (vitorias_visitante / total_jogos_visitante) * 100 if total_jogos_visitante > 0 else 0
print(f"\nPorcentagem de vitórias fora de casa: {percentual_vitorias_visitante:.2f}%")


gols_feitos_visitante = df_tite[df_tite["Venue"] == "Away"]["GF"].sum()
gols_feitos_visitante_media = df_tite[df_tite["Venue"] == "Away"]["GF"].mean()

gols_concedidos_visitante = df_tite[df_tite["Venue"] == "Away"]["GA"].sum()
gols_concedidos_visitante_media =  df_tite[df_tite["Venue"] == "Away"]["GA"].mean()


print(f"Gols feitos fora de casa (Total): {gols_feitos_visitante}")
print(f"Gols feitos fora de casa (Média): {gols_feitos_visitante_media:.2f}")
print(f"Gols concedidos fora de casa (Total): {gols_concedidos_visitante}")
print(f"Gols concedidos fora de casa (Média): {gols_concedidos_visitante_media:.2f}")
# Out:
#  === Desempenho fora de casa ===
#
# Porcentagem de vitórias fora de casa: 27.78%
# Gols feitos fora de casa (Total): 24
# Gols feitos fora de casa (Média): 1.33
# Gols concedidos fora de casa (Total): 24
# Gols concedidos fora de casa (Média): 1.33

# %%
# começando analises do flamengo de Felipe Luís (fl)

print(" ======================= Analises do flamengo de Felipe Luís (fl) =======================")
# Resultados com o Felipe Luís (fl)
df_derrotas_fl = df_2025[df_2025["Result"] == "L"].shape[0]
df_empates_fl = df_2025[df_2025["Result"] == "D"].shape[0]
df_vitorias_fl = df_2025[df_2025["Result"] == "W"].shape[0]

print(f"O flamengo de Felipe Luís (fl) deve: ", df_derrotas_fl, " derrotas, ", df_empates_fl, " empates e ", df_vitorias_fl , " vitorias")

# como era o desempenho tático?
# média de posse de bola
media_posse_fl = df_2025["Poss"].mean()
print(f"Média de posse de bola do Flamengo de Felipe Luís (fl): {media_posse_fl:.2f}")

# formação mais usada
formacao_mais_usada_fl = df_2025["Formation"].max()
# formação menos usada
formacao_menos_usada_fl = df_2025["Formation"].min()
print(f"Formação mais usada: ", formacao_mais_usada_fl, "VS formação menos usada: ", formacao_menos_usada_fl)

# Média de xG, gols esperados
media_xG_fl = df_2025["xG"].mean()
print(f"Média de xG:  {media_xG_fl:.2f}")

# Média de xGA, gols esperados que aconteceram
media_xGA_fl = df_2025["xGA"].mean()
print(f"Média xGA: {media_xGA_fl:.2f}")


# Desempenho em casa
print("\n === Desempenho em casa === ")

# Número total de jogos em casa
total_jogos_casa_fl = df_2025[df_2025["Venue"] == "Home"].shape[0]

# Número de vitórias em casa
vitorias_casa_fl = df_2025[(df_2025["Venue"] == "Home") & (df_2025["Result"] == "W")].shape[0]

# Média de vitórias em casa (percentual de vitórias)
percentual_vitorias_casa_fl = (vitorias_casa_fl / total_jogos_casa_fl) * 100 if total_jogos_casa_fl > 0 else 0
print(f"\nPorcentagem de vitórias em casa: {percentual_vitorias_casa_fl:.2f}%")

# Média de xG em casa
media_xG_casa_fl = df_2025[df_2025["Venue"] == "Home"]["xG"].mean()
print(f"Média de xG em casa: {media_xG_casa_fl:.2f}")

# Gols feitos em casa
gols_feitos_casa_fl = df_2025[df_2025["Venue"] == "Home"]["GF"].sum()
gols_feitos_casa_media_fl = gols_feitos_casa_fl / total_jogos_casa_fl if total_jogos_casa_fl > 0 else 0
print(f"Gols feitos em casa (Total): {gols_feitos_casa_fl}")
print(f"Gols feitos em casa (Média): {gols_feitos_casa_media_fl:.2f}")

# Gols concedidos em casa
gols_concedidos_casa_fl = df_2025[df_2025["Venue"] == "Home"]["GA"].sum()
gols_concedidos_casa_media_fl = gols_concedidos_casa_fl / total_jogos_casa_fl if total_jogos_casa_fl > 0 else 0
print(f"Gols concedidos em casa (Total): {gols_concedidos_casa_fl}")
print(f"Gols concedidos em casa (Média): {gols_concedidos_casa_media_fl:.2f}")
# Out:
#  ======================= Analises do flamengo de Felipe Luís (fl) =======================
# O flamengo de Felipe Luís (fl) deve:  1  derrotas,  5  empates e  6  vitorias
# Média de posse de bola do Flamengo de Felipe Luís (fl): 59.25
# Formação mais usada:  nan VS formação menos usada:  3-4-3
# Média de xG:  1.78
# Média xGA: 0.81
#
#  === Desempenho em casa ===
#
# Porcentagem de vitórias em casa: 7.41%
# Média de xG em casa: 1.97
# Gols feitos em casa (Total): 10.0
# Gols feitos em casa (Média): 0.37
# Gols concedidos em casa (Total): 9.0
# Gols concedidos em casa (Média): 0.33
